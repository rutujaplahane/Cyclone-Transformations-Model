# %% [markdown]
# ### 1. Global and Variable Attributes

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

file_paths = [
    r"E:\ML Project\WOSC Project\EarthFormer\Data\amphan_2020-05-06_to_2020-06-04.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\asani_2022-04-27_to_2022-05-26.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\dana_2024-10-12_to_2024-11-10.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\fani_2019-04-16_to_2019-05-15.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\gulab_2021-09-14_to_2021-10-13.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\hudhud_2014-09-27_to_2014-10-26.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\phailin_2013-09-24_to_2013-10-23.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\titli_2018-09-28_to_2018-10-27.nc",
    r"E:\ML Project\WOSC Project\EarthFormer\Data\yaas_2021-05-13_to_2021-06-11.nc" 
]

datasets = []

for path in file_paths:
    ds = xr.open_dataset(path)
    datasets.append(ds)

for i, ds in enumerate(datasets):
    print(f"\n================ Cyclone {i+1} ================\n")
    
    print(ds)
    print("\nGlobal attributes:")
    print(ds.attrs)

for i, ds in enumerate(datasets):
    print(f"\n================ Cyclone {i+1} ================\n")

    print("\nVariables Attributes:")
    for var in ds.data_vars:
        print(var, ds[var].attrs)
# Out:
# ================ Cyclone 1 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2020-05-06 2020-05-07 ... 2020-06-04
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 2 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2022-04-27 2022-04-28 ... 2022-05-26
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 3 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2024-10-12 2024-10-13 ... 2024-11-10
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 4 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2019-04-16 2019-04-17 ... 2019-05-15
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 5 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2021-09-14 2021-09-15 ... 2021-10-13
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 6 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2014-09-27 2014-09-28 ... 2014-10-26
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 7 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2013-09-24 2013-09-25 ... 2013-10-23
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 8 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2018-09-28 2018-09-29 ... 2018-10-27
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 9 ================
#
# <xarray.Dataset> Size: 143MB
# Dimensions:    (time: 30, depth: 33, latitude: 60, longitude: 60)
# Coordinates:
#   * time       (time) datetime64[ns] 240B 2021-05-13 2021-05-14 ... 2021-06-11
#   * depth      (depth) int16 66B 0 5 10 15 20 25 30 ... 400 450 500 550 600 700
#   * latitude   (latitude) float32 240B 15.06 15.19 15.31 ... 22.19 22.31 22.44
#   * longitude  (longitude) float32 240B 82.56 82.69 82.81 ... 89.69 89.81 89.94
# Data variables:
#     to         (time, depth, latitude, longitude) float64 29MB ...
#     so         (time, depth, latitude, longitude) float64 29MB ...
#     ugo        (time, depth, latitude, longitude) float64 29MB ...
#     vgo        (time, depth, latitude, longitude) float64 29MB ...
#     zo         (time, depth, latitude, longitude) float64 29MB ...
# Attributes:
#     Conventions:               CF-1.0
#     description:               ARMOR3D REP Copernicus Marine Service November...
#     domain_name:               GLO
#     history:                   2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global...
#     institution:               CLS
#     lat_max:                   89.9375
#     lat_min:                   -82.1875
#     lon_max:                   179.9375
#     lon_min:                   -179.9375
#     title:                     ARMOR3D REP - TSHUVMld Global Ocean Observatio...
#     copernicusmarine_version:  2.3.0
#
# Global attributes:
# {'Conventions': 'CF-1.0', 'description': 'ARMOR3D REP Copernicus Marine Service November 2025 Release', 'domain_name': 'GLO', 'history': '2025-10-11 04:04:02 ARMOR3D REP - TSHUV Global Ocean Observation-based Product netCDF creation', 'institution': 'CLS', 'lat_max': np.float64(89.9375), 'lat_min': np.float64(-82.1875), 'lon_max': np.float64(179.9375), 'lon_min': np.float64(-179.9375), 'title': 'ARMOR3D REP - TSHUVMld Global Ocean Observation-based Product', 'copernicusmarine_version': '2.3.0'}
#
# ================ Cyclone 1 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 2 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 3 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 4 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 5 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 6 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 7 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 8 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}
#
# ================ Cyclone 9 ================
#
#
# Variables Attributes:
# to {'long_name': 'temperature', 'standard_name': 'sea_water_temperature', 'unit_long': 'degree Celsius', 'units': 'degrees_C'}
# so {'long_name': 'salinity', 'standard_name': 'sea_water_salinity', 'unit_long': 'practical salinity unit', 'units': '0.001'}
# ugo {'long_name': 'geostrophic zonal velocity from thermal wind equation', 'standard_name': 'geostrophic_eastward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# vgo {'long_name': 'geostrophic meridional velocity from thermal wind equation', 'standard_name': 'geostrophic_northward_sea_water_velocity', 'unit_long': 'meter per second', 'units': 'm s-1', 'valid_range': array([-4000,  4000], dtype=int16)}
# zo {'long_name': 'absolute height', 'standard_name': 'geopotential_height', 'unit_long': 'meter', 'units': 'm', 'valid_range': array([-20000,  20000], dtype=int16)}

# %% [markdown]
# ### 2. Coordinates and Physical Ranges of Variables

# %%
for i, ds in enumerate(datasets):
    print(f"\n================ Cyclone {i+1} ================\n")

    print("\nLatitude:", ds.latitude.values[:3], "...", ds.latitude.values[-3:])
    print("Longitude:", ds.longitude.values[:3], "...", ds.longitude.values[-3:])
    print("Depth:", ds.depth.values)
    print("Time:", ds.time.values[:2], "...", ds.time.values[-2:])

for i, ds in enumerate(datasets):
    print(f"\n================ Cyclone {i+1} ================\n")

    # Loop over all data variables
    for var in ds.data_vars:
        da = ds[var]

        print(f"\n{var}")
        print("Min:", float(da.min()))
        print("Max:", float(da.max()))
        print("Mean:", float(da.mean()))
# Out:
# ================ Cyclone 1 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2020-05-06T00:00:00.000000000' '2020-05-07T00:00:00.000000000'] ... ['2020-06-03T00:00:00.000000000' '2020-06-04T00:00:00.000000000']
#
# ================ Cyclone 2 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2022-04-27T00:00:00.000000000' '2022-04-28T00:00:00.000000000'] ... ['2022-05-25T00:00:00.000000000' '2022-05-26T00:00:00.000000000']
#
# ================ Cyclone 3 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2024-10-12T00:00:00.000000000' '2024-10-13T00:00:00.000000000'] ... ['2024-11-09T00:00:00.000000000' '2024-11-10T00:00:00.000000000']
#
# ================ Cyclone 4 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2019-04-16T00:00:00.000000000' '2019-04-17T00:00:00.000000000'] ... ['2019-05-14T00:00:00.000000000' '2019-05-15T00:00:00.000000000']
#
# ================ Cyclone 5 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2021-09-14T00:00:00.000000000' '2021-09-15T00:00:00.000000000'] ... ['2021-10-12T00:00:00.000000000' '2021-10-13T00:00:00.000000000']
#
# ================ Cyclone 6 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2014-09-27T00:00:00.000000000' '2014-09-28T00:00:00.000000000'] ... ['2014-10-25T00:00:00.000000000' '2014-10-26T00:00:00.000000000']
#
# ================ Cyclone 7 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2013-09-24T00:00:00.000000000' '2013-09-25T00:00:00.000000000'] ... ['2013-10-22T00:00:00.000000000' '2013-10-23T00:00:00.000000000']
#
# ================ Cyclone 8 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2018-09-28T00:00:00.000000000' '2018-09-29T00:00:00.000000000'] ... ['2018-10-26T00:00:00.000000000' '2018-10-27T00:00:00.000000000']
#
# ================ Cyclone 9 ================
#
#
# Latitude: [15.0625 15.1875 15.3125] ... [22.1875 22.3125 22.4375]
# Longitude: [82.5625 82.6875 82.8125] ... [89.6875 89.8125 89.9375]
# Depth: [  0   5  10  15  20  25  30  35  40  45  50  55  60  65  70  80  90 100
#  125 150 175 200 225 250 275 300 350 400 450 500 550 600 700]
# Time: ['2021-05-13T00:00:00.000000000' '2021-05-14T00:00:00.000000000'] ... ['2021-06-10T00:00:00.000000000' '2021-06-11T00:00:00.000000000']
#
# ================ Cyclone 1 ================
#
#
# to
# Min: 8.09
# Max: 32.966
# Mean: 21.56973090420472
#
# so
# Min: 30.849
# Max: 35.223
# Mean: 34.2356736282344
#
# ugo
# Min: -0.8290000000000001
# Max: 0.9460000000000001
# Mean: -0.023583047624648378
#
# vgo
# Min: -0.723
# Max: 1.004
# Mean: 0.0016997276117228918
#
# zo
# Min: -0.676
# Max: 1.366
# Mean: 0.3800603291476409
#
# ================ Cyclone 2 ================
#
#
# to
# Min: 8.055
# Max: 31.667
# Mean: 21.8536219744102
#
# so
# Min: 29.599
# Max: 35.797
# Mean: 34.06940722650304
#
# ugo
# Min: -0.801
# Max: 1.119
# Mean: 0.015036843188567735
#
# vgo
# Min: -0.928
# Max: 1.054
# Mean: 0.007626492066266583
#
# zo
# Min: -0.704
# Max: 1.412
# Mean: 0.39399098316210046
#
# ================ Cyclone 3 ================
#
#
# to
# Min: 8.177
# Max: 31.767
# Mean: 20.650201629090564
#
# so
# Min: 27.098
# Max: 35.066
# Mean: 33.9511141690449
#
# ugo
# Min: -1.2710000000000001
# Max: 0.716
# Mean: -0.06580140649043881
#
# vgo
# Min: -1.114
# Max: 1.025
# Mean: -0.02809724844141467
#
# zo
# Min: -0.636
# Max: 1.603
# Mean: 0.33667239250380515
#
# ================ Cyclone 4 ================
#
#
# to
# Min: 7.943
# Max: 32.088
# Mean: 21.402183156392695
#
# so
# Min: 30.451999999999998
# Max: 35.921
# Mean: 34.21883304746956
#
# ugo
# Min: -1.0230000000000001
# Max: 1.29
# Mean: 0.05627211865486587
#
# vgo
# Min: -0.807
# Max: 0.811
# Mean: 0.003996370098467633
#
# zo
# Min: -0.747
# Max: 1.337
# Mean: 0.3423505997907154
#
# ================ Cyclone 5 ================
#
#
# to
# Min: 8.263
# Max: 32.176
# Mean: 21.20632407962329
#
# so
# Min: 26.681
# Max: 35.345
# Mean: 33.9527269744102
#
# ugo
# Min: -0.969
# Max: 0.602
# Mean: -0.041802047497231126
#
# vgo
# Min: -0.672
# Max: 0.518
# Mean: -0.010810142943152908
#
# zo
# Min: -0.631
# Max: 1.506
# Mean: 0.3860848606354642
#
# ================ Cyclone 6 ================
#
#
# to
# Min: 8.198
# Max: 32.376
# Mean: 20.691343237252664
#
# so
# Min: 27.482
# Max: 35.247
# Mean: 34.0163118902207
#
# ugo
# Min: -1.0190000000000001
# Max: 0.634
# Mean: -0.060059514638282026
#
# vgo
# Min: -0.797
# Max: 0.658
# Mean: 0.007361487405076814
#
# zo
# Min: -0.649
# Max: 1.556
# Mean: 0.3530493093607306
#
# ================ Cyclone 7 ================
#
#
# to
# Min: 7.984999999999999
# Max: 32.730000000000004
# Mean: 20.512068495528922
#
# so
# Min: 25.758
# Max: 35.503
# Mean: 34.05450997526636
#
# ugo
# Min: -1.016
# Max: 0.5750000000000001
# Mean: -0.039287560155645065
#
# vgo
# Min: -1.141
# Max: 0.762
# Mean: -0.015653792072093067
#
# zo
# Min: -0.639
# Max: 1.355
# Mean: 0.34014064212328765
#
# ================ Cyclone 8 ================
#
#
# to
# Min: 7.9879999999999995
# Max: 32.363
# Mean: 20.14734399686073
#
# so
# Min: 27.149
# Max: 35.51
# Mean: 34.16947816590563
#
# ugo
# Min: -0.771
# Max: 0.47800000000000004
# Mean: -0.03832990433904751
#
# vgo
# Min: -0.9540000000000001
# Max: 0.708
# Mean: -0.009891677348559887
#
# zo
# Min: -0.64
# Max: 1.306
# Mean: 0.31897312880517503
#
# ================ Cyclone 9 ================
#
#
# to
# Min: 8.253
# Max: 32.641
# Mean: 21.765758863203956
#
# so
# Min: 31.661
# Max: 35.193
# Mean: 34.163197897640785
#
# ugo
# Min: -0.777
# Max: 0.983
# Mean: 0.026960741764434908
#
# vgo
# Min: -0.856
# Max: 0.836
# Mean: 0.023228446367185223
#
# zo
# Min: -0.664
# Max: 1.36
# Mean: 0.3957429556697108

# %% [markdown]
# ### 3. Missing values

# %%
for i, ds in enumerate(datasets):
    print(f"\n================ Cyclone {i+1} ================\n")

    # Loop over all data variables
    for var in ds.data_vars:
        da = ds[var]

        print(f"\n--- Variable: {var} ---")

        # 1. NaN Stats
        total_points = da.size
        nan_count = np.isnan(da).sum().item()
        nan_frac = nan_count / total_points

        print(f"{var}:")
        print(f"  Total points   : {total_points:,}")
        print(f"  NaN count      : {nan_count:,}")
        print(f"  NaN fraction   : {nan_frac:.4f}")

        # 2. Fill values 
        print("_FillValue:", da.attrs.get("_FillValue"))
        print("missing_value:", da.attrs.get("missing_value"))

        # 3. Mask Stability across Variables
        print(f"\n================ Cyclone {i+1} ================\n")
        mask_ref = np.isnan(ds["to"])
        for var in ds.data_vars:
            same = np.all(mask_ref == np.isnan(ds[var]))
            print(var, "same mask:", same)
# Out:
# ================ Cyclone 1 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 1 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 1 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 1 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 1 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 1 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 2 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 2 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 2 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 2 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 2 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 2 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 3 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 3 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 3 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 3 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 3 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 3 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 4 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 4 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 4 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 4 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 4 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 4 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 5 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 5 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 5 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 5 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 5 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 5 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 6 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 6 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 6 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 6 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 6 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 6 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 7 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 7 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 7 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 7 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 7 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 7 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 8 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 8 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 8 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 8 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 8 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 8 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# ================ Cyclone 9 ================
#
#
# --- Variable: to ---
# to:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 9 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: so ---
# so:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 9 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: ugo ---
# ugo:
#   Total points   : 3,564,000
#   NaN count      : 1,523,460
#   NaN fraction   : 0.4275
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 9 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: vgo ---
# vgo:
#   Total points   : 3,564,000
#   NaN count      : 1,504,440
#   NaN fraction   : 0.4221
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 9 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]
#
# --- Variable: zo ---
# zo:
#   Total points   : 3,564,000
#   NaN count      : 1,461,600
#   NaN fraction   : 0.4101
# _FillValue: None
# missing_value: None
#
# ================ Cyclone 9 ================
#
# to same mask: <xarray.DataArray 'to' ()> Size: 1B
# array(True)
# Attributes:
#     long_name:      temperature
#     standard_name:  sea_water_temperature
#     unit_long:      degree Celsius
#     units:          degrees_C
# so same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# ugo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# vgo same mask: <xarray.DataArray ()> Size: 1B
# array(False)
# Attributes:
#     valid_range:  [-4000  4000]
# zo same mask: <xarray.DataArray ()> Size: 1B
# array(True)
# Attributes:
#     valid_range:  [-20000  20000]

# %% [markdown]
# ### 4. Check Plots

# %% [markdown]
# Vertical Profiles

# %%
for i, ds in enumerate(datasets):
    print(f"\n================ Cyclone {i+1} ================\n")
    ds["to"].isel(time=0, latitude=40, longitude=50).plot(y="depth")
    plt.gca().invert_yaxis()
    plt.title("Temperature vertical profile")
    plt.show()
# Out:
# ================ Cyclone 1 ================
# ================ Cyclone 2 ================
# ================ Cyclone 3 ================
# ================ Cyclone 4 ================
# ================ Cyclone 5 ================
# ================ Cyclone 6 ================
# ================ Cyclone 7 ================
# ================ Cyclone 8 ================
# ================ Cyclone 9 ================

# %% [markdown]
# Temporal Evolution at a Point

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 28,
    'axes.titlesize': 40,
    'axes.labelsize': 34,
    'xtick.labelsize': 26,
    'ytick.labelsize': 26,
    'legend.fontsize': 28
})

CYCLONES = ["Amphan","Asani","Dana","Fani",
            "Gulab","Hudhud","Phailin","Titli","Yaas"]

FORMATION_DATES = {
    "Phailin": "2013-10-04",
    "Hudhud": "2014-10-07",
    "Asani": "2022-05-07",
    "Titli": "2018-10-08",
    "Fani": "2019-04-26",
    "Amphan": "2020-05-16",
    "Yaas": "2021-05-23",
    "Dana": "2024-10-22",
    "Gulab": "2021-09-24"
}

LAT_INDEX = 40
LON_INDEX = 50

for i, ds in enumerate(datasets):

    cyclone_name = CYCLONES[i]

    temp = ds["to"].isel(depth=0, latitude=LAT_INDEX, longitude=LON_INDEX)
    sal  = ds["so"].isel(depth=0, latitude=LAT_INDEX, longitude=LON_INDEX)
    height = ds["zo"].isel(depth=0, latitude=LAT_INDEX, longitude=LON_INDEX)

    lat_value = float(ds.latitude[LAT_INDEX].values)
    lon_value = float(ds.longitude[LON_INDEX].values)

    time = temp.time.values
    formation_date = pd.to_datetime(FORMATION_DATES[cyclone_name])

    # ---------------- Figure ----------------
    fig, ax1 = plt.subplots(figsize=(18, 12))

    # Second and third y-axis
    ax2 = ax1.twinx()
    ax3 = ax1.twinx()

    # Move third axis outward
    ax3.spines["right"].set_position(("outward", 100))

    # ---------------- Plot Lines ----------------
    line1 = ax1.plot(time, temp.values, color="darkred", linewidth=4, label="Temperature")
    line2 = ax2.plot(time, sal.values, color="darkblue", linewidth=4, label="Salinity")
    line3 = ax3.plot(time, height.values, color="darkgreen", linewidth=4, label="Absolute Height")

    # ---------------- Colored Y Labels ----------------
    ax1.set_ylabel("Temperature (°C)", color="darkred")
    ax2.set_ylabel("Salinity (psu)", color="darkblue")
    ax3.set_ylabel("Absolute Height (m)", color="darkgreen")

    ax1.tick_params(axis='y', colors="darkred")
    ax2.tick_params(axis='y', colors="darkblue")
    ax3.tick_params(axis='y', colors="darkgreen")

    # ---------------- Formation Line ----------------
    ax1.axvline(formation_date, color="black", linestyle="--", linewidth=4)

    ax1.text(
        formation_date,
        ax1.get_ylim()[1],
        "FORMATION",
        fontsize=34,
        rotation=90,
        verticalalignment='top',
        horizontalalignment='right'
    )

    # ---------------- X Axis ----------------
    ax1.xaxis.set_major_locator(mdates.DayLocator(interval=3))
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d %b %Y'))
    ax1.tick_params(axis='x', rotation=40)
    ax1.set_xlabel("Time (UTC)")

    # ---------------- Title ----------------
    plt.title(
        f"Cyclone {cyclone_name} – Surface Ocean Response\n"
        f"Depth = 0 m (Surface) | Location: {lat_value:.2f}°N, {lon_value:.2f}°E",
        fontsize=36,
        fontweight="bold"
    )

    # ---------------- Legend ----------------
    lines = line1 + line2 + line3
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc="upper right")

    # ---------------- Save ----------------
    plt.tight_layout()
    plt.savefig(f"{cyclone_name}_combined_poster.png", dpi=300, bbox_inches='tight')
    plt.show()

# %% [markdown]
# Surface Temperature Plot on 1st Day

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

CYCLONES = ["Amphan","Asani","Dana","Fani",
            "Gulab","Hudhud","Phailin","Titli","Yaas"]

for i, ds in enumerate(datasets):
    print(f"\n================ Cyclone {i+1} ================\n")
    
    #Visual sanity plot
    ds["to"].isel(time=0, depth=0).plot()
    plt.title("Surface Temperature (first day)")
    plt.show()
